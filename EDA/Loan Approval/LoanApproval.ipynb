# %% [markdown]
# # Project Objectives:
#
#     1. Load the Data
#     2. Clean the Data
#     3. Explore the Data (Main Question : Which client profile is more likely to have an approved loan)

# %% [markdown]
# # Loan Approval : Financial Risk Analysis

# %% [markdown]
# ## Loading and Previewing the Data

# %%
print("hello")
# Out:
# hello

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("Loan.csv")
df.head()
# Out:
#   ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0      2018-01-01   45         39948          617         Employed
# 1      2018-01-02   38         39709          628         Employed
# 2      2018-01-03   47         40724          570         Employed
# 3      2018-01-04   58         69084          545         Employed
# 4      2018-01-05   37        103264          594         Employed
#
#   EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  ...  \
# 0         Master          22       13152            48       Married  ...
# 1      Associate          15       26045            48        Single  ...
# 2       Bachelor          26       17627            36       Married  ...
# 3    High School          34       37898            96        Single  ...
# 4      Associate          17        9184            36       Married  ...
#
#    MonthlyIncome UtilityBillsPaymentHistory  JobTenure  NetWorth  \
# ...

# %%
df.tail()
# Out:
#       ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 19995      2072-09-29   44         30180          587         Employed
# 19996      2072-09-30   56         49246          567         Employed
# 19997      2072-10-01   44         48958          645         Employed
# 19998      2072-10-02   60         41025          560         Employed
# 19999      2072-10-03   20         53227          574         Employed
#
#       EducationLevel  Experience  LoanAmount  LoanDuration MaritalStatus  ...  \
# 19995    High School          19       24521            36       Married  ...
# 19996      Associate          33       25818            36       Married  ...
# 19997       Bachelor          20       37033            72       Married  ...
# 19998    High School          36       14760            72       Married  ...
# 19999      Associate           0       32055            48       Married  ...
#
# ...

# %%
df.isna().sum()
# Out:
# ApplicationDate               0
# Age                           0
# AnnualIncome                  0
# CreditScore                   0
# EmploymentStatus              0
# EducationLevel                0
# Experience                    0
# LoanAmount                    0
# LoanDuration                  0
# MaritalStatus                 0
# NumberOfDependents            0
# HomeOwnershipStatus           0
# MonthlyDebtPayments           0
# CreditCardUtilizationRate     0
# NumberOfOpenCreditLines       0
# NumberOfCreditInquiries       0
# DebtToIncomeRatio             0
# BankruptcyHistory             0
# LoanPurpose                   0
# PreviousLoanDefaults          0
# PaymentHistory                0
# LengthOfCreditHistory         0
# SavingsAccountBalance         0
# CheckingAccountBalance        0
# TotalAssets                   0
# TotalLiabilities              0
# MonthlyIncome                 0
# UtilityBillsPaymentHistory    0
# JobTenure                     0
# ...

# %% [markdown]
# ## Cleaning the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ApplicationDate             20000 non-null  object
#  1   Age                         20000 non-null  int64
#  2   AnnualIncome                20000 non-null  int64
#  3   CreditScore                 20000 non-null  int64
#  4   EmploymentStatus            20000 non-null  object
#  5   EducationLevel              20000 non-null  object
#  6   Experience                  20000 non-null  int64
#  7   LoanAmount                  20000 non-null  int64
#  8   LoanDuration                20000 non-null  int64
#  9   MaritalStatus               20000 non-null  object
#  10  NumberOfDependents          20000 non-null  int64
#  11  HomeOwnershipStatus         20000 non-null  object
#  12  MonthlyDebtPayments         20000 non-null  int64
# ...

# %% [markdown]
#     ApplicationDate needs to be changed to Date

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# ApplicationDate               0
# Age                           0
# AnnualIncome                  0
# CreditScore                   0
# EmploymentStatus              0
# EducationLevel                0
# Experience                    0
# LoanAmount                    0
# LoanDuration                  0
# MaritalStatus                 0
# NumberOfDependents            0
# HomeOwnershipStatus           0
# MonthlyDebtPayments           0
# CreditCardUtilizationRate     0
# NumberOfOpenCreditLines       0
# NumberOfCreditInquiries       0
# DebtToIncomeRatio             0
# BankruptcyHistory             0
# LoanPurpose                   0
# PreviousLoanDefaults          0
# PaymentHistory                0
# LengthOfCreditHistory         0
# SavingsAccountBalance         0
# CheckingAccountBalance        0
# TotalAssets                   0
# TotalLiabilities              0
# MonthlyIncome                 0
# UtilityBillsPaymentHistory    0
# JobTenure                     0
# ...

# %%
# Checking for Duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Converting the ApplicationDate column to DATEtype
df['ApplicationDate'] = pd.to_datetime(df['ApplicationDate'])

# %%
# Checking on the data type of various columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ApplicationDate             20000 non-null  datetime64[ns]
#  1   Age                         20000 non-null  int64
#  2   AnnualIncome                20000 non-null  int64
#  3   CreditScore                 20000 non-null  int64
#  4   EmploymentStatus            20000 non-null  object
#  5   EducationLevel              20000 non-null  object
#  6   Experience                  20000 non-null  int64
#  7   LoanAmount                  20000 non-null  int64
#  8   LoanDuration                20000 non-null  int64
#  9   MaritalStatus               20000 non-null  object
#  10  NumberOfDependents          20000 non-null  int64
#  11  HomeOwnershipStatus         20000 non-null  object
#  12  MonthlyDebtPayments         20000 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['ApplicationDate', 'Age', 'AnnualIncome', 'CreditScore',
#        'EmploymentStatus', 'EducationLevel', 'Experience', 'LoanAmount',
#        'LoanDuration', 'MaritalStatus', 'NumberOfDependents',
#        'HomeOwnershipStatus', 'MonthlyDebtPayments',
#        'CreditCardUtilizationRate', 'NumberOfOpenCreditLines',
#        'NumberOfCreditInquiries', 'DebtToIncomeRatio', 'BankruptcyHistory',
#        'LoanPurpose', 'PreviousLoanDefaults', 'PaymentHistory',
#        'LengthOfCreditHistory', 'SavingsAccountBalance',
#        'CheckingAccountBalance', 'TotalAssets', 'TotalLiabilities',
#        'MonthlyIncome', 'UtilityBillsPaymentHistory', 'JobTenure', 'NetWorth',
#        'BaseInterestRate', 'InterestRate', 'MonthlyLoanPayment',
#        'TotalDebtToIncomeRatio', 'LoanApproved', 'RiskScore'],
#       dtype='object')

# %%
# Columns of Interest

#Defining the columns you want to keep
columns_of_Interest = ['ApplicationDate', 'Age', 'AnnualIncome', 'CreditScore',
       'EmploymentStatus', 'LoanAmount','HomeOwnershipStatus', 'SavingsAccountBalance','TotalAssets',
         'TotalLiabilities','JobTenure', 'LoanApproved']

# Create a new DataFrame with only the specified columns
loans = df[columns_of_Interest]

loans.head()
# Out:
#   ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0      2018-01-01   45         39948          617         Employed
# 1      2018-01-02   38         39709          628         Employed
# 2      2018-01-03   47         40724          570         Employed
# 3      2018-01-04   58         69084          545         Employed
# 4      2018-01-05   37        103264          594         Employed
#
#    LoanAmount HomeOwnershipStatus  SavingsAccountBalance  TotalAssets  \
# 0       13152                 Own                   7632       146111
# 1       26045            Mortgage                   4627        53204
# 2       17627                Rent                    886        25176
# 3       37898            Mortgage                   1675       104822
# 4        9184            Mortgage                   1555       244305
#
#    TotalLiabilities  JobTenure  LoanApproved
# 0             19183         11             0
# 1              9595          3             0
# ...

# %%
# Check the shape
loans.shape
# Out:
# (20000, 12)

# %% [markdown]
# ## Data Exploration and Visualization

# %%
# Checking on the data points of interest
loans.columns
# Out:
# Index(['ApplicationDate', 'Age', 'AnnualIncome', 'CreditScore',
#        'EmploymentStatus', 'LoanAmount', 'HomeOwnershipStatus',
#        'SavingsAccountBalance', 'TotalAssets', 'TotalLiabilities', 'JobTenure',
#        'LoanApproved'],
#       dtype='object')

# %% [markdown]
#     Applications over Time

# %%
loans.tail(2)
# Out:
#       ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 19998      2072-10-02   60         41025          560         Employed
# 19999      2072-10-03   20         53227          574         Employed
#
#        LoanAmount HomeOwnershipStatus  SavingsAccountBalance  TotalAssets  \
# 19998       14760                 Own                   3037        22085
# 19999       32055                 Own                   2682        83008
#
#        TotalLiabilities  JobTenure  LoanApproved
# 19998             11485          5             0
# 19999             41636          5             0

# %%
loans = loans.iloc[:-1]
loans.tail()
# Out:
#       ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 19994      2072-09-28   51         33354          562         Employed
# 19995      2072-09-29   44         30180          587         Employed
# 19996      2072-09-30   56         49246          567         Employed
# 19997      2072-10-01   44         48958          645         Employed
# 19998      2072-10-02   60         41025          560         Employed
#
#        LoanAmount HomeOwnershipStatus  SavingsAccountBalance  TotalAssets  \
# 19994       22082                 Own                   6489       239447
# 19995       24521                Rent                    235        80969
# 19996       25818                Rent                   6910        69571
# 19997       37033            Mortgage                   2175       108316
# 19998       14760                 Own                   3037        22085
#
#        TotalLiabilities  JobTenure  LoanApproved
# ...

# %%
# Extract the year and month from the 'ApplicationDate'
loans['Year'] = loans['ApplicationDate'].apply(lambda x : str(x).split('-')[0])
loans['Month'] = loans['ApplicationDate'].apply(lambda x : str(x).split('-')[1])

# %%
# loans.loc[:, 'Year'] = loans['ApplicationDate'].apply(lambda x : str(x).split('-')[0])
# loans.loc[:, 'Month'] = loans['ApplicationDate'].apply(lambda x : str(x).split('-')[1])

# %%
loans.head()
# Out:
#   ApplicationDate  Age  AnnualIncome  CreditScore EmploymentStatus  \
# 0      2018-01-01   45         39948          617         Employed
# 1      2018-01-02   38         39709          628         Employed
# 2      2018-01-03   47         40724          570         Employed
# 3      2018-01-04   58         69084          545         Employed
# 4      2018-01-05   37        103264          594         Employed
#
#    LoanAmount HomeOwnershipStatus  SavingsAccountBalance  TotalAssets  \
# 0       13152                 Own                   7632       146111
# 1       26045            Mortgage                   4627        53204
# 2       17627                Rent                    886        25176
# 3       37898            Mortgage                   1675       104822
# 4        9184            Mortgage                   1555       244305
#
#    TotalLiabilities  JobTenure  LoanApproved  Year Month
# 0             19183         11             0  2018    01
# ...

# %%
# Group by year and count applications
applications_per_year = loans.groupby(['Year','LoanApproved'], as_index=False)['LoanApproved'].value_counts()

plt.figure(figsize=(10,12))

sns.barplot(data = applications_per_year, y= 'Year', x= 'count', hue= 'LoanApproved')
plt.show()

# %%
loans.groupby(['Year','LoanApproved'])['LoanApproved'].sum()
# Out:
# Year  LoanApproved
# 2018  0                0
#       1               95
# 2019  0                0
#       1               82
# 2020  0                0
#                       ..
# 2070  1               81
# 2071  0                0
#       1               78
# 2072  0                0
#       1               69
# Name: LoanApproved, Length: 110, dtype: int64

# %% [markdown]
#     Annual Income

# %%
##AnnualIncome
#ApplicationDate
#EmploymentStatus
#LoanAmount
#HomeOwnershipStatus
#LoanApproved

# Measures of Central Tendency

mean_AI = round(loans['AnnualIncome'].mean(),2)
mode_AI = round(loans['AnnualIncome'].mode())
median_AI = round(loans['AnnualIncome'].median(),2)

'''.quantile(0.25): This calculates the 25th percentile 
(also known as the first quartile) of the 'AnnualIncome' values. 
The 25th percentile means that 25% of the data points in 
the 'AnnualIncome' column are below this value.'''

percent25_AI = round(loans['AnnualIncome'].quantile(0.25),2)

'''.quantile(0.75): This calculates the 75th percentile 
(also known as the third quartile) of the 'AnnualIncome' values. 
The 75th percentile means that 75% of the data points in the 'AnnualIncome' column are below this value.'''
percent75_AI = round(loans['AnnualIncome'].quantile(0.75),2)

# %%
print(f' Mean = {mean_AI}')
print(f' Mode = {mode_AI}')
print(f' Median = {median_AI}')
print(f' 25th Percentile = {percent25_AI}')
print(f' 75th Percentile = {percent75_AI}')
# Out:
#  Mean = 59161.77
#  Mode = 0    15000
# Name: AnnualIncome, dtype: int64
#  Median = 48565.0
#  25th Percentile = 31678.0
#  75th Percentile = 74394.0

# %%
#Majority of the clients who get their loans approved are at what income level?

# Defining the function that will categorize income levels
def income_category(AnnualIncome):
    if AnnualIncome <= percent25_AI:
        return f'Lower Income (<= {percent25_AI})'
    elif AnnualIncome <= median_AI:
        return f'Lower-Middle Income (<= {median_AI})'
    elif AnnualIncome <= percent75_AI:
        return f'Upper-Middle Income (<= {percent75_AI})'
    else:
        return f'High Income (> {percent75_AI})'
    
loans['Income Category'] = loans['AnnualIncome'].apply(income_category)
loans[['Income Category', 'AnnualIncome']]
# Out:
#                         Income Category  AnnualIncome
# 0      Lower-Middle Income (<= 48565.0)         39948
# 1      Lower-Middle Income (<= 48565.0)         39709
# 2      Lower-Middle Income (<= 48565.0)         40724
# 3      Upper-Middle Income (<= 74394.0)         69084
# 4               High Income (> 74394.0)        103264
# ...                                 ...           ...
# 19994  Lower-Middle Income (<= 48565.0)         33354
# 19995         Lower Income (<= 31678.0)         30180
# 19996  Upper-Middle Income (<= 74394.0)         49246
# 19997  Upper-Middle Income (<= 74394.0)         48958
# 19998  Lower-Middle Income (<= 48565.0)         41025
#
# [19999 rows x 2 columns]

# %%
# # Grouping by 'Income Category' and counting the number of people in each category
# applications_per_category = loans.groupby('Income Category', as_index= False)['Income Category'].size().sort_values('size', ascending= False)
# applications_per_category.head()
# Out:
#                     Income Category  size
# 0           High Income (> 74394.0)  5000
# 1         Lower Income (<= 31678.0)  5000
# 2  Lower-Middle Income (<= 48565.0)  5000
# 3  Upper-Middle Income (<= 74394.0)  4999

# %%
# Grouping by 'Income Category' and counting the number of people in each category
applications_per_category = loans.groupby('Income Category')['Income Category'].size().reset_index(name= 'Number_of_Applicants')
applications_per_category = applications_per_category.sort_values('Number_of_Applicants', ascending= False)
applications_per_category.head()
# Out:
#                     Income Category  Number_of_Applicants
# 0           High Income (> 74394.0)                  5000
# 1         Lower Income (<= 31678.0)                  5000
# 2  Lower-Middle Income (<= 48565.0)                  5000
# 3  Upper-Middle Income (<= 74394.0)                  4999

# %%
sns.barplot(data= applications_per_category, y= 'Income Category', x= 'Number_of_Applicants')
# Out:
# <Axes: xlabel='Number_of_Applicants', ylabel='Income Category'>

# %%
loansApproval_per_category = loans.groupby(['Income Category', 'LoanApproved']).size().reset_index(name = 'Number_of_Applicants')

# %%
loansApproval_per_category.head()
# Out:
#                     Income Category  LoanApproved  Number_of_Applicants
# 0           High Income (> 74394.0)             0                  1777
# 1           High Income (> 74394.0)             1                  3223
# 2         Lower Income (<= 31678.0)             0                  4948
# 3         Lower Income (<= 31678.0)             1                    52
# 4  Lower-Middle Income (<= 48565.0)             0                  4658

# %%
plt.figure(figsize=(10,6))

myplot = sns.barplot(data= loansApproval_per_category, x= 'Income Category', y= 'Number_of_Applicants', hue= 'LoanApproved', errorbar= None)

for bar in myplot.containers:
    myplot.bar_label(bar, 
                     labels= [f'{v:0.0f}' for v in bar.datavalues],
                     padding= 2)

plt.title("Loan Approval rate spread Across Income Category",
          fontdict= {'fontsize' : 14,
                     'fontweight' : 'bold',
                     'color': '#89332a'})
plt.xlabel("Annual Income Category",
          fontdict= {'fontsize' : 12,
                     'fontweight' : 'bold',
                     'color': '#89332a'})
plt.xticks(ticks= [0,1,2,3], labels= ['High Income', 'Low Income', 'Low-Middle Income', 'High-Middle Income'])
plt.ylabel("Number of Applications",
          fontdict= {'fontsize' : 14,
                     'fontweight' : 'bold',
                     'color': '#89332a'})


myplot.legend(labels=['NA','A'], title = 'Approvals', loc = 'upper right')
plt.tight_layout()
plt.show()

# %%
loansApproval_per_category_sorted = loansApproval_per_category.sort_values(['LoanApproved','Number_of_Applicants'], ascending= [False,True])

# %%
loansApproval_per_category_sorted
# Out:
#                     Income Category  LoanApproved  Number_of_Applicants
# 3         Lower Income (<= 31678.0)             1                    52
# 5  Lower-Middle Income (<= 48565.0)             1                   342
# 7  Upper-Middle Income (<= 74394.0)             1                  1163
# 1           High Income (> 74394.0)             1                  3223
# 0           High Income (> 74394.0)             0                  1777
# 6  Upper-Middle Income (<= 74394.0)             0                  3836
# 4  Lower-Middle Income (<= 48565.0)             0                  4658
# 2         Lower Income (<= 31678.0)             0                  4948

# %%
plt.figure(figsize=(10,6))

myplot = sns.barplot(data= loansApproval_per_category_sorted, x= 'Income Category', y= 'Number_of_Applicants',
                     hue= 'LoanApproved',
                     width= 0.6,
                     errorbar= None)

for bar in myplot.containers:
    myplot.bar_label(bar, 
                     labels= [f'{v:0.0f}' for v in bar.datavalues],
                     padding= 2)
for bars in myplot.containers:
    for bar in bars:
        bar.set_alpha(0.8)
plt.title("Loan Approval rate spread Across Income Category",
          fontdict= {'fontsize' : 14,
                     'fontweight' : 'bold',
                     'color': '#89332a'})
plt.xlabel("Annual Income Category",
          fontdict= {'fontsize' : 12,
                     'fontweight' : 'bold',
                     'color': '#89332a'})
plt.xticks(ticks= [0,1,2,3], labels= ['Low Income', 'Low-Middle Income', 'Upper-Middle Income', 'High Income'])
plt.ylabel("Number of Applications",
          fontdict= {'fontsize' : 14,
                     'fontweight' : 'bold',
                     'color': '#89332a'})


myplot.legend(labels=['NA','A'], title = 'Approvals', loc = 'upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Insights: Annual Income and Approval rate is Indirectly proportional to each other
