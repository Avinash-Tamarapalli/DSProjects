# %% [markdown]
#     Importing DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('sample_dataset.csv')
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          NaN         10.38          122.80     1001.0           0.1184
# 1        20.57         17.77          132.90     1326.0              NaN
# 2        19.69         21.25          130.00     1203.0           0.1096
# 3        11.42         20.38           77.58      386.1           0.1425
# 4        20.29         14.34             NaN        NaN              NaN
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0            0.2776          0.3001              0.14710         0.2419
# 1               NaN          0.0869              0.07017            NaN
# 2            0.1599             NaN                  NaN            NaN
# 3            0.2839          0.2414                  NaN         0.2597
# 4            0.1328          0.1980                  NaN         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              482 non-null    float64
#  1   mean texture             492 non-null    float64
#  2   mean perimeter           513 non-null    float64
#  3   mean area                403 non-null    float64
#  4   mean smoothness          384 non-null    float64
#  5   mean compactness         480 non-null    float64
#  6   mean concavity           439 non-null    float64
#  7   mean concave points      382 non-null    float64
#  8   mean symmetry            471 non-null    float64
#  9   mean fractal dimension   504 non-null    float64
#  10  radius error             475 non-null    float64
#  11  texture error            434 non-null    float64
#  12  perimeter error          381 non-null    float64
# ...

# %%
round((df.isnull().sum()/df.shape[0]) * 100, 2).sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
#     Summarization

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   482.000000    492.000000      513.000000   403.000000
# mean     14.059548     19.311829       92.039025   661.522581
# std       3.501791      4.347769       24.028669   356.669534
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.672500     16.170000       75.270000   428.100000
# 50%      13.280000     18.860000       86.340000   556.700000
# 75%      15.745000     21.802500      104.700000   796.000000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       384.000000        480.000000      439.000000           382.000000
# mean          0.097156          0.104531        0.094063             0.049115
# std           0.014502          0.053335        0.083301             0.038449
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.describe(percentiles=[0.05,0.25,0.5,0.75,0.95])
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   482.000000    492.000000      513.000000   403.000000
# mean     14.059548     19.311829       92.039025   661.522581
# std       3.501791      4.347769       24.028669   356.669534
# min       6.981000      9.710000       43.790000   143.500000
# 5%        9.439400     13.071000       60.922000   279.690000
# 25%      11.672500     16.170000       75.270000   428.100000
# 50%      13.280000     18.860000       86.340000   556.700000
# 75%      15.745000     21.802500      104.700000   796.000000
# 95%      20.569000     27.700000      135.780000  1307.100000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       384.000000        480.000000      439.000000           382.000000
# mean          0.097156          0.104531        0.094063             0.049115
# ...

# %%
df.describe(include=['object'])
# Out:
#        area error
# count         494
# unique          3
# top             A
# freq          489

# %%
df['area error'].value_counts()
# Out:
# area error
# A    489
# B      4
# C      1
# Name: count, dtype: int64

# %% [markdown]
#     Histogram

# %%
df.iloc[:, 0:4].hist(bins= 20)
# Out:
# array([[<Axes: title={'center': 'mean radius'}>,
#         <Axes: title={'center': 'mean texture'}>],
#        [<Axes: title={'center': 'mean perimeter'}>,
#         <Axes: title={'center': 'mean area'}>]], dtype=object)

# %%
df.iloc[:, 0:4].hist(bins= 'rice')
#rice criterion decides bins according to columns
# Out:
# array([[<Axes: title={'center': 'mean radius'}>,
#         <Axes: title={'center': 'mean texture'}>],
#        [<Axes: title={'center': 'mean perimeter'}>,
#         <Axes: title={'center': 'mean area'}>]], dtype=object)

# %% [markdown]
#     Boxplots

# %%
df.head(2)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          NaN         10.38           122.8     1001.0           0.1184
# 1        20.57         17.77           132.9     1326.0              NaN
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0            0.2776          0.3001              0.14710         0.2419
# 1               NaN          0.0869              0.07017            NaN
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33              NaN      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
#
#   worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0           0.1622             0.6656           0.7119                0.2654
# 1           0.1238             0.1866           0.2416                0.1860
#
#    worst symmetry  worst fractal dimension  target
# ...

# %%
df[['mean radius']].boxplot()
# Out:
# <Axes: >

# %%
df.iloc[:, 0:5].boxplot()
# this gives the orders of magnitude of each feature
# Out:
# <Axes: >

# %% [markdown]
#     Pariplots

# %%
sns.pairplot(df.iloc[:, 0:5])

# %%
sns.pairplot(df.iloc[0:100,0:5],kind= 'hist')

# %%
sns.pairplot(df.iloc[0:100,0:5],kind= 'kde')

# %%
sns.pairplot(df, x_vars= ['mean radius', 'mean texture', 'mean area'],
             y_vars= ['mean radius', 'mean texture'],
             hue= 'target')

# %%
sns.pairplot(df, x_vars= ['mean radius', 'mean texture', 'mean area'],
             y_vars= ['mean radius', 'mean texture'],
             hue= 'area error')

# %% [markdown]
#     Correlation matrix and histograms

# %%
from sklearn.preprocessing import LabelEncoder 

df['area error'] = LabelEncoder().fit_transform(df['area error'])

df.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.325048        0.997917   0.985544
# mean texture                0.325048      1.000000        0.346173   0.331863
# mean perimeter              0.997917      0.346173        1.000000   0.984596
# mean area                   0.985544      0.331863        0.984596   1.000000
# mean smoothness             0.174663     -0.027530        0.216465   0.243077
# mean compactness            0.538038      0.194730        0.543423   0.511137
# mean concavity              0.669628      0.266315        0.699639   0.688334
# mean concave points         0.824008      0.318055        0.841415   0.833180
# mean symmetry               0.133417      0.050521        0.179526   0.227485
# mean fractal dimension     -0.300202     -0.084390       -0.255071  -0.261360
# radius error                0.677570      0.260308        0.684500   0.761143
# ...

# %%
df.iloc[:,0:4].corr(method= "spearman")
# Out:
#                 mean radius  mean texture  mean perimeter  mean area
# mean radius        1.000000      0.344725        0.997749   0.999576
# mean texture       0.344725      1.000000        0.359269   0.359408
# mean perimeter     0.997749      0.359269        1.000000   0.996912
# mean area          0.999576      0.359408        0.996912   1.000000

# %% [markdown]
#     Heatmap

# %%
plt.figure(figsize= (14,9))

sns.heatmap(df.corr().abs(), cmap= 'coolwarm')

plt.show()

# %% [markdown]
#     Stacked Histogram

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          NaN         10.38          122.80     1001.0           0.1184
# 1        20.57         17.77          132.90     1326.0              NaN
# 2        19.69         21.25          130.00     1203.0           0.1096
# 3        11.42         20.38           77.58      386.1           0.1425
# 4        20.29         14.34             NaN        NaN              NaN
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0            0.2776          0.3001              0.14710         0.2419
# 1               NaN          0.0869              0.07017            NaN
# 2            0.1599             NaN                  NaN            NaN
# 3            0.2839          0.2414                  NaN         0.2597
# 4            0.1328          0.1980                  NaN         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
sns.histplot(data= df, x= 'mean radius', hue= 'target', multiple= 'stack')
# Out:
# <Axes: xlabel='mean radius', ylabel='Count'>

# %%
sns.histplot(data= df, x= 'mean fractal dimension', hue= 'target', multiple= 'stack')
# Out:
# <Axes: xlabel='mean fractal dimension', ylabel='Count'>

# %%
columns = df.select_dtypes(exclude= 'object').drop('target', axis= 1).columns

# %%
columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension'],
#       dtype='object')

# %%
fig, axs = plt.subplots(len(columns), 1, figsize=(5, 5 * len(columns)))


for i in range(len(columns)):
    column_name = columns[i]
    sns.histplot(data= df, x= column_name, hue= 'target', multiple= 'stack', ax= axs[i])

plt.show()

# %% [markdown]
#      Sweetviz

# %%
import sweetviz

# %%
report = sweetviz.analyze(df, target_feat= 'target')
# Out:
# Feature: mean radius                         |▋         | [  6%]   00:01 -> (00:17 left)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 report = sweetviz.analyze(df, target_feat= 'target')
#
# File c:\Users\2165362\OneDrive - Cognizant\Desktop\Programmes\DSProjects\dsprojects\Lib\site-packages\sweetviz\sv_public.py:12, in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
#      13                                       pairwise_analysis, feat_cfg)
#      14     return report
#
# ...
