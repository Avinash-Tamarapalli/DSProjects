# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("zomato.csv", encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ## Basic Things to do for Data Analysis
#
# 1. Missing Values
# 2. Explore about the Numerical Variables
# 3. Explore about the Categorical Variables
# 4. Finding Relationship between Features

# %% [markdown]
# ### 1. Missing Values

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[feature for feature in df.columns if df[feature].isnull().sum() > 0]
# Out:
# ['Cuisines']

# %%
sns.heatmap(df.isnull(), yticklabels=False, cmap='coolwarm')


# since 9 in 9551 is minute, we can't observe the shades of nan values
# Out:
# <Axes: >

# %%
df_country = pd.read_excel('Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %% [markdown]
#     Combining the Two DataFrames

# %%
final_df = pd.merge(df, df_country, on='Country Code', how='left')

# %%
final_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#To check Data Types
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %% [markdown]
#     Exploring

# %%
country_names = final_df.Country.value_counts().index

# %%
country_values = final_df.Country.value_counts().values

# %%
#Pie Chart - Top 3 Countries that uses Zomato

plt.pie(x=country_values[:3],labels= country_names[:3], autopct= '%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2bddb393710>,
# ...
#  [Text(-1.082974277862112, 0.1927867046480056, 'India'),
#   Text(1.0772816964394372, -0.22240536530526556, 'United States'),
#   Text(1.0995865232164619, -0.030157552300104404, 'United Kingdom')],
#  [Text(-0.5907132424702428, 0.10515638435345759, '94.39%'),
#   Text(0.5876081980578747, -0.12131201743923574, '4.73%'),
#   Text(0.5997744672089791, -0.01644957398187513, '0.87%')])

# %% [markdown]
#     Observation:
# The Maximum Transactions for Zomato comes from India, then followed by US and UK with 4.73% and 0.87% respectively

# %% [markdown]
# ### 2. Explore about the Numerical Variables

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
ratings = final_df.groupby(['Aggregate rating' , 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
#     Observations:
# 1. When Rating is between 4.5 to 4.9 -----------> Excellent
# 2. When Rating is between 4.0 to 4.4 -----------> Very Good
# 3. When Rating is between 3.5 to 3.9 -----------> Good
# 4. When Rating is between 2.5 to 3.4 -----------> Average
# 5. When Rating is between 1.8 to 2.4 -----------> Poor
# 6. When Rating is 0.0 --------------------------> No Rating

# %%
# BAR PLOT


plt.figure(figsize=(12,6))

sns.barplot(data = ratings, x = "Aggregate rating", y = "Rating Count", hue = 'Rating text' , palette='viridis', legend = False)
plt.show()

# %%
# list(ratings['Rating color'].unique())

# %%
plt.figure(figsize=(12,6))

sns.barplot(data = ratings, x = "Aggregate rating", y = "Rating Count", hue = 'Rating color' , palette= list(ratings['Rating color'].unique()), legend = False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 3
#       1 plt.figure(figsize=(12,6))
# ----> 3 sns.barplot(data = ratings, x = "Aggregate rating", y = "Rating Count", hue = 'Rating color' , palette= list(ratings['Rating color'].unique()), legend = False)
#       4 plt.show()
#
# File c:\Users\2165362\OneDrive - Cognizant\Desktop\Programmes\DSProjects\dsprojects\Lib\site-packages\seaborn\categorical.py:2380, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2377 # Deprecations to remove in v0.15.0.
#    2378 err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
# -> 2380 p.plot_bars(
# ...

# %%
plt.figure(figsize=(12,6))

sns.barplot(data = ratings, x = "Aggregate rating", y = "Rating Count", hue = 'Rating text' , palette= ['Black', 'Red', 'Orange', 'Yellow', 'Green', 'Blue'], legend = True)
plt.show()

# %% [markdown]
#     Observations:
# 1. There are high number of people who have NOT RATED
# 2. Second highest falls between 2.9 to 3.8

# %%
# COUNT PLOT

plt.figure(figsize=(12,6))

sns.countplot(data = ratings, x = 'Rating color', palette= ['Black', 'Red', 'Orange', 'Yellow', 'Green', 'Blue'])

# the plot on y-axis shows frequency, don't confuse it with Rating count in ratings DF
plt.show()
# Out:
# C:\Users\2165362\AppData\Local\Temp\ipykernel_25964\1394409783.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = ratings, x = 'Rating color', palette= ['Black', 'Red', 'Orange', 'Yellow', 'Green', 'Blue'])

# %%
### Find the countries name that has given 0 rating
final_df[final_df['Aggregate rating'] == 0]['Country'].value_counts().reset_index()
# Out:
#           Country  count
# 0           India   2139
# 1          Brazil      5
# 2   United States      3
# 3  United Kingdom      1

# %% [markdown]
#     Observations:
# Indian Customers give maximum number of Zero Ratings

# %%
## Find out which currency is used by which country?

final_df.groupby(['Country','Currency']).size()
# Out:
# Country         Currency
# Australia       Dollar($)                   24
# Brazil          Brazilian Real(R$)          60
# Canada          Dollar($)                    4
# India           Indian Rupees(Rs.)        8652
# Indonesia       Indonesian Rupiah(IDR)      21
# New Zealand     NewZealand($)               40
# Phillipines     Botswana Pula(P)            22
# Qatar           Qatari Rial(QR)             20
# Singapore       Dollar($)                   20
# South Africa    Rand(R)                     60
# Sri Lanka       Sri Lankan Rupee(LKR)       20
# Turkey          Turkish Lira(TL)            34
# UAE             Emirati Diram(AED)          60
# United Kingdom  Pounds(£)                  80
# United States   Dollar($)                  434
# dtype: int64

# %%
## Which Countries do have online deliveries

final_df[final_df['Has Online delivery'] == 'Yes']['Country'].value_counts()
# Out:
# Country
# India    2423
# UAE        28
# Name: count, dtype: int64

# %% [markdown]
#     Observations:
# Online Delivery is only available in India and UAE

# %%
final_df.groupby(['Country' , 'Has Online delivery']).size().reset_index().rename(columns={0:'Count'})
# Out:
#            Country Has Online delivery  Count
# 0        Australia                  No     24
# 1           Brazil                  No     60
# 2           Canada                  No      4
# 3            India                  No   6229
# 4            India                 Yes   2423
# 5        Indonesia                  No     21
# 6      New Zealand                  No     40
# 7      Phillipines                  No     22
# 8            Qatar                  No     20
# 9        Singapore                  No     20
# 10    South Africa                  No     60
# 11       Sri Lanka                  No     20
# 12          Turkey                  No     34
# 13             UAE                  No     32
# 14             UAE                 Yes     28
# 15  United Kingdom                  No     80
# 16   United States                  No    434

# %% [markdown]
#     Observations:
# Seems like Online Delivery is not available in some places in India too

# %%
# Create a pie chart for cities distribution

plt.pie(x = final_df['City'].value_counts().values[:5],
        labels= final_df['City'].value_counts().index[:5],
        autopct="%0.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2bdde6fd050>,
# ...
#  [Text(-0.6145353730323401, 0.9123301350344637, 'New Delhi'),
#   Text(0.06236774886414425, -1.0982305149200777, 'Gurgaon'),
#   Text(0.878904221413572, -0.6614585169014024, 'Noida'),
#   Text(1.0922218482114119, -0.1305811406354216, 'Faridabad'),
#   Text(1.099946277419523, -0.010871374841004297, 'Ghaziabad')],
#  [Text(-0.33520111256309454, 0.4976346191097074, '68.87%'),
#   Text(0.03401877210771504, -0.5990348263200423, '14.07%'),
#   Text(0.479402302589221, -0.36079555467349217, '13.59%'),
#   Text(0.5957573717516791, -0.07122607671022996, '3.16%'),
#   Text(0.5999706967742853, -0.00592984082236598, '0.31%')])

# %%
# Find the top 10 cuisines
final_df[final_df['Cuisines'] == 'French, Japanese, Desserts']
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
#
#   Is delivering now Switch to order menu Price range Aggregate rating  \
# 0                No                   No           3              4.8
#
#    Rating color  Rating text Votes      Country
# 0    Dark Green    Excellent   314  Phillipines
#
# [1 rows x 22 columns]
